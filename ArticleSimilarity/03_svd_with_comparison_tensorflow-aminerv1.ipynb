# %% [markdown]
# # SVD with TensorFlow

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl

import numpy as np
import scipy.spatial as sp
import tensorflow as tf

import matrices.loading as matload
import resources.dataset as rsdata
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
plt.rcParams["figure.figsize"] = (4,4)
mpl.rcParams['figure.dpi']= 200
mpl.rcParams['figure.titlesize']= 'xx-large'
mpl.rcParams['font.size']= 6
mpl.rcParams['image.cmap'] = 'jet'
cmap = cm.get_cmap('jet')
cmap.set_bad('w') # Print bads as white

sess = tf.Session() # tensorflow

# %%
data_path = "resources/aminer/v1" # 629814 documents

# %%
# Load sparse matrix with jaccard similarities.
matrix_tmp = matload.load_matrix_jaccard_sim(data_path)

n = matrix_tmp.shape[0]

matrix_jaccard = tf.constant(matrix_tmp, name='matrix_jaccard')

# dice
matrix_dice = tf.constant(np.divide(np.multiply(2,matrix_tmp), np.add(matrix_tmp, 1)), name='matrix_dice')

# Jaccard disimilarity
matrix_jaccard_dis =  tf.constant(np.subtract(1, matrix_tmp), name='matrix_jaccard_dis')

del matrix_tmp

# Load sparse matrix with word2vec similarities.
matrix_tmp = matload.load_matrix_word2vec_sim(data_path)

matrix_word2vec = tf.constant(matrix_tmp, name='matrix_word2vec')

del matrix_tmp

pltmask =  np.tri(n, k=-1) # Mask to plot upper triangular matrix.   

# Load document ids in the Same order than the matrices
indexdocs = matload.get_document_ids(data_path)

print("\nMatrices.")
print(matrix_jaccard)
print(matrix_jaccard_dis)
print(matrix_dice)
print(matrix_word2vec)
# Out:
# Loading saved matrix ...
# Loading saved matrix ...
#
# Matrices.
# Tensor("matrix_jaccard:0", shape=(998, 998), dtype=float32)
# Tensor("matrix_jaccard_dis:0", shape=(998, 998), dtype=float32)
# Tensor("matrix_dice:0", shape=(998, 998), dtype=float32)
# Tensor("matrix_word2vec:0", shape=(998, 998), dtype=float32)

# %%
# Tensors 
M = tf.Variable(tf.zeros((n,n),  dtype=tf.float32), dtype=tf.float32, name='M') 
s, u, v = tf.svd(M) #SVD

# ns = n
ns = 1 # one singular value

# UDV' matrix reconstruction with ns singular values
M_ = tf.matmul(u[:,:ns], tf.matmul(tf.diag(s[:ns]), v[:,:ns], adjoint_b=True)) 
# M_ = tf.matmul(u[:,:ns], v[:,:ns], adjoint_b=True) # UV'

sess.run(tf.global_variables_initializer())  

print("Tensors for SVD. \nM_ is the reconstruction of the matrix M with %d singular value(s)." % (ns))
# Out:
# Tensors for SVD.
# M_ is the reconstruction of the matrix M with 1 singular value(s).

# %%
op = M.assign(matrix_jaccard)
sess.run(op)
jaccard_approximation = sess.run(M_) # Reconstruction of the matrix M
jaccard_singular_values = sess.run(s) # Singular values  

op = M.assign(matrix_jaccard_dis)
sess.run(op)
jaccarddis_approximation = sess.run(M_)
jaccarddis_singular_values = sess.run(s)

op = M.assign(matrix_dice)
sess.run(op)
dice_approximation = sess.run(M_)
dice_singular_values = sess.run(s)

op = M.assign(matrix_word2vec)
sess.run(op)
word2vec_approximation = sess.run(M_)
word2vec_singular_values = sess.run(s)

print("Matrix reconstructions using %d singular value(s)" % (ns))
# Out:
# Matrix reconstructions using 1 singular value(s)

# %%
print("SVD: Largest singular values:\n \
        \nJaccard sim. s0 = %f \nJaccard dis. s0 = %f \nDice sim. s0 = %f \
        \nwod2vec sim. s0 = %f" % (jaccard_singular_values[0], jaccarddis_singular_values[0], 
      dice_singular_values[0], word2vec_singular_values[0]))
# Out:
# SVD: Largest singular values:
#
# Jaccard sim. s0 = 9.587548
# Jaccard dis. s0 = 990.752136
# Dice sim. s0 = 16.390749
# wod2vec sim. s0 = 101.521500

# %% [markdown]
# ### Plotting the matrix approximations
#
# In the following graphs $s_0$ is not plotted because it is too large in the cases of wod2vec and jaccard disimilarities.

# %%
fig = plt.figure(figsize=(4, 3))
fig.suptitle("SVD - %d singular value(s), without s0" % (n - 1))

# Plotting singular values. s0 is too large for word2vec
ax1 = plt.subplot(1, 1, 1)
ax1.plot(jaccard_singular_values[1:], 'b.', mew=1.0, ms=3.0, label="Jaccard sim.")
ax1.plot(jaccarddis_singular_values[1:], 'm.', mew=1.0, ms=1.0, label="Jaccard dis.")
ax1.plot(dice_singular_values[1:], 'g.', mew=1.0, ms=1.0, label="Dice sim.")
ax1.plot(word2vec_singular_values[1:], 'r.', mew=1.0, ms=1.0, label="Word2vec sim.")

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,14))
fig.suptitle("SVD - Plots using %d singular value(s)" % (ns))

ax_jaccard = plt.subplot(4, 2, 1)
ax_jaccard.set_title("Jaccard similarities (original)")
im_jaccard = ax_jaccard.imshow(np.ma.array(sess.run(matrix_jaccard), mask=pltmask))
plt.colorbar(im_jaccard)
# Reconstructed matrix using the largest singular value.
ax_jaccard_ = plt.subplot(4, 2, 2)
ax_jaccard_.set_title("Jaccard similarities (UDV')")
im_jaccard_ = ax_jaccard_.imshow(np.ma.array(jaccard_approximation, mask=pltmask))

plt.colorbar(im_jaccard_)

ax_jaccard_dis = plt.subplot(4, 2, 3)
ax_jaccard_dis.set_title("Jaccard disimilarities (original)")
im_jaccarddis = ax_jaccard_dis.imshow(np.ma.array(sess.run(matrix_jaccard_dis), mask=pltmask))
plt.colorbar(im_jaccarddis)
# Reconstructed matrix using the largest singular value.
ax_jaccard_dis_ = plt.subplot(4, 2, 4)
ax_jaccard_dis_.set_title("Jaccard disimilarities (UDV')")
im_jaccarddis_ = ax_jaccard_dis_.imshow(np.ma.array(jaccarddis_approximation, mask=pltmask))
plt.colorbar(im_jaccarddis_)

ax_dice = plt.subplot(4, 2, 5)
ax_dice.set_title("Dice similarities (original)")
im_dice = ax_dice.imshow(np.ma.array(sess.run(matrix_dice), mask=pltmask))
plt.colorbar(im_dice)
# Reconstructed matrix using the largest singular value.
ax_dice_ = plt.subplot(4, 2, 6)
ax_dice_.set_title("Dice similarities (UDV')")
im_dice_ = ax_dice_.imshow(np.ma.array(dice_approximation, mask=pltmask))
plt.colorbar(im_dice_)

ax_word2vec = plt.subplot(4, 2, 7)
ax_word2vec.set_title("Word2vec similarities (original)")
im_word2vec = ax_word2vec.imshow(np.ma.array(sess.run(matrix_word2vec), mask=pltmask))
plt.colorbar(im_word2vec)
# Reconstructed matrix using the largest singular value.
ax_word2vec_ = plt.subplot(4, 2, 8)
ax_word2vec_.set_title("Word2vec similarities (UDV')")
im_word2vec_ = ax_word2vec_.imshow(np.ma.array(word2vec_approximation, mask=pltmask))
plt.colorbar(im_word2vec_)

plt.show()

# %% [markdown]
# ### Ordering matrices for better visualization
#
# From the matrix approximations with SVD is calculated the mean for each column. Later, the means are used to order the matrices.

# %%
# Means of jaccard similarities using the reconstructed matrix 
jaccard_similarity_mean = tf.reduce_mean(jaccard_approximation, 1)
# Ordered indices by mean of similarities in the approximation
jaccard_indices = sess.run(jaccard_similarity_mean).argsort()[::-1]

# Means of word2vec similarities using the reconstructed matrix 
word2vec_similarity_mean = tf.reduce_mean(word2vec_approximation, 1)
# Ordered indices by mean of similarities in the approximation
word2vec_indices = sess.run(word2vec_similarity_mean).argsort()[::-1]

# %%
fig = plt.figure(figsize=(12,5))
fig.suptitle("Ordering columns by means of word2vec similarities")

ax_jaccard = plt.subplot(1, 2, 1)
ax_jaccard.set_title("Jaccard similarities (approximation)")
im_jaccard_arranged = ax_jaccard.imshow(np.ma.array(
    jaccard_approximation[:,word2vec_indices][word2vec_indices,:], mask=pltmask))
plt.colorbar(im_jaccard_arranged)

ax_word2vec = plt.subplot(1, 2, 2)
ax_word2vec.set_title("Word2vec similarities (approximation)")
im_word2vec_arranged = ax_word2vec.imshow(np.ma.array(
    word2vec_approximation[:,word2vec_indices][word2vec_indices,:], mask=pltmask))
plt.colorbar(im_word2vec_arranged)

plt.show()

# %% [markdown]
# A mask is generated from jaccard similarities, given $s_{ij} \in S$ with S being the matrix, the mask is the matrix K.
#
# \begin{equation}
#   k_{ij}=\left\{
#   \begin{array}{@{}ll@{}}
#     1, & \text{if}\ s_{ij}=0 \\
#     0, & \text{otherwise}
#   \end{array}\right.
# \end{equation}
#
# Each similarity equal to zero with jaccard means that between two documents there is not a correspondence in words.

# %%
# Mask
jaccard_mask = sess.run(tf.where( tf.equal(matrix_jaccard, 0.0), 
                                 tf.ones(matrix_jaccard.get_shape()), tf.zeros(matrix_jaccard.get_shape())))

jaccard_mask_ordered = jaccard_mask[:,word2vec_indices][word2vec_indices,:]

with sess.as_default():
    print("Jaccard matrix\n", matrix_jaccard[:3,:3].eval())
    print("\nJaccard mask\n", jaccard_mask[:3,:3])
# Out:
# Jaccard matrix
#  [[1.         0.14285715 0.        ]
#  [0.14285715 1.         0.        ]
#  [0.         0.         1.        ]]
#
# Jaccard mask
#  [[0. 0. 1.]
#  [0. 0. 1.]
#  [1. 1. 0.]]

# %% [markdown]
# The mask is aplyed over word2vec by multiplying each element in the matrix $s_{ij}k_{ij}$ (not matrix multiplication).

# %%
# Mask over word2vec
jaccardmask_word2vecapprox = sess.run(tf.convert_to_tensor(jaccard_mask)*word2vec_approximation)
jaccardmask_word2vecapprox_ordered = jaccardmask_word2vecapprox[:,word2vec_indices][word2vec_indices,:]

with sess.as_default():
    # The resulting word2vec matrix keeps only values of similitaties 
    # where jaccard has a similarity of zero
    print("Small example with the mask.")
    print("\nword2vec (approx.)\n", word2vec_approximation[:3,:3])
    print("\nMaskered word2vec\n", jaccardmask_word2vecapprox[:3,:3])
# Out:
# Small example with the mask.
#
# word2vec (approx.)
#  [[0.07846789 0.06433386 0.10137664]
#  [0.06433419 0.05274599 0.0831166 ]
#  [0.10137682 0.08311632 0.13097385]]
#
# Maskered word2vec
#  [[0.         0.         0.10137664]
#  [0.         0.         0.0831166 ]
#  [0.10137682 0.08311632 0.        ]]

# %% [markdown]
# This mask is only used to illustrate that similar documents don't necessarily have co-occurrence of words.

# %%
fig = plt.figure(figsize=(12,5))
fig.suptitle("Mask over word2vec")

ax_mask = plt.subplot(1, 2, 1)
ax_mask.set_title("Mask (red meaning jaccard_sim is equal to 0)")
im_mask = ax_mask.imshow(
                np.ma.array(
                    jaccard_mask_ordered, 
                    mask=pltmask
                )
            )
plt.colorbar(im_mask)

ax_jm_wa = plt.subplot(1, 2, 2)
ax_jm_wa.set_title("Mask over word2vec")
im_jm_wa = ax_jm_wa.imshow(
                np.ma.array(
                    jaccardmask_word2vecapprox_ordered, 
                    mask=pltmask
                )
            )
plt.colorbar(im_jm_wa)
plt.show()

# %%
size_submatrix = 200
subpltmask = pltmask[:size_submatrix,:size_submatrix]

# %%
fig = plt.figure(figsize=(12,5))
fig.suptitle("Mask over word2vec (%dx%d)" % (size_submatrix, size_submatrix))

ax_mask_seg = plt.subplot(1, 2, 1)
ax_mask_seg.set_title("Mask (%d)" % size_submatrix )
im_mask_seg = ax_mask_seg.imshow(
                np.ma.array(
                    jaccard_mask_ordered[:size_submatrix,:size_submatrix], 
                    mask=subpltmask
                )
            )
plt.colorbar(im_mask_seg)

ax_jm_wa_seg = plt.subplot(1, 2, 2)
ax_jm_wa_seg.set_title("Mask over word2vec (%d)" % size_submatrix )
im_jm_wa_seg = ax_jm_wa_seg.imshow(
                np.ma.array(
                    jaccardmask_word2vecapprox_ordered[:size_submatrix,:size_submatrix], 
                    mask=subpltmask
                )
            )
plt.colorbar(im_jm_wa_seg)

plt.show()

# %%
def freq_zero_jaccard_sim_triu(JM):
    N_JM_i, N_JM_j = JM.shape
    zero_sim = 0
    gt_zero = 0
    total_values = 0
    for i in range(0, N_JM_i):
        j = i+1
        while j < N_JM_j:
            total_values += 1
            if JM[i,j] == 1:
                zero_sim += 1
            else:
                gt_zero += 1
            j += 1
    return zero_sim/total_values, gt_zero/total_values

def freq_zero_jaccard_sim_full(JM):
    N_JM_i, N_JM_j = JM.shape
    zero_sim = 0
    gt_zero = 0
    total_values = 0
    for i in range(0, N_JM_i):
        j = 0
        while j < N_JM_j:
            total_values += 1
            if JM[i,j] == 1:
                zero_sim += 1
            else:
                gt_zero += 1
            j += 1
    return zero_sim/total_values, gt_zero/total_values

# %%
fig = plt.figure(figsize=(12,10))

n_subms = int(np.ceil(n/size_submatrix).tolist())
center_size_submatrix = size_submatrix/2
vmax=jaccardmask_word2vecapprox_ordered.max()

zero_sim_freq_full, gt_zero_sim_freq_full = freq_zero_jaccard_sim_triu(jaccard_mask_ordered)

fig.suptitle("Freq. of similarities >0.0 (submatrices %dx%d)" % (size_submatrix, size_submatrix))

for i_subimage in range(0, n_subms):
    m_istart = i_subimage * size_submatrix
    m_iend = (i_subimage + 1) * size_submatrix
    j_subimage = i_subimage
    while j_subimage < n_subms:   
        m_jstart = j_subimage * size_submatrix
        m_jend = (j_subimage + 1) * size_submatrix
        
        submatrix_tmp = jaccardmask_word2vecapprox_ordered[m_istart:m_iend,m_jstart:m_jend]
        submask_tmp = jaccard_mask_ordered[m_istart:m_iend, m_jstart:m_jend]
        zero_sim_freq, gt_zero_sim_freq = freq_zero_jaccard_sim_triu(submask_tmp) if i_subimage == j_subimage else freq_zero_jaccard_sim_full(submask_tmp) 
        
        plt.subplot(n_subms, n_subms, j_subimage + (i_subimage*n_subms) + 1)     
        plt.text(center_size_submatrix - 60, 
                        center_size_submatrix + 10, 
                        '%.5f' % (gt_zero_sim_freq), 
                        fontsize=14, 
                        color='black',
                        bbox={'facecolor':'white', 'alpha':0.5, 'pad':5}
                   )
        
        im = plt.imshow(
                    np.ma.array(
                        submatrix_tmp, 
                        mask = subpltmask[:submatrix_tmp.shape[0],:submatrix_tmp.shape[0]] if i_subimage == j_subimage else None
                    ),
                    vmin=0.0, vmax=vmax
                )
        j_subimage += 1 

fig.text(0.3, 0.3, 'Freq. of similarities >0.0 in \nJaccard matrix = %.5f' % gt_zero_sim_freq_full, ha='center', va='center', size=15)

plt.show()

# %% [markdown]
# # Data samples

# %% [markdown]
# ## Document ids orderedby word2vec means.

# %%
indexdocs_ordered_word2vec = np.array(indexdocs)[word2vec_indices]
ix_data = rsdata.cur_indexed_docs(data_path)
ix_data_sample = rsdata.cur_indexed_sample(data_path)

# %% [markdown]
# ## words from n documents

# %%
n_documents = 100

print("First %d documents in the ordered graph\n" % n_documents)
# print(indexdocs_ordered_word2vec[:n_documents])
for idoc in indexdocs_ordered_word2vec[:n_documents]:
    result = rsdata.find_indexdoc(ix_data_sample, idoc)
    for r in result:
        print(r['indexdoc'], r['bag_of_words'])
        
print("\n\nLast %d documents in the ordered graph\n" % n_documents)
# print(indexdocs_ordered_word2vec[-n_documents:])
for idoc in indexdocs_ordered_word2vec[-n_documents:]:
    result = rsdata.find_indexdoc(ix_data_sample, idoc)
    for r in result:
        print(r['indexdoc'], r['bag_of_words'])
        
print("\n%d documents in the ordered graph\n" % n_documents)
# print(indexdocs_ordered_word2vec[-n_documents:])
for idoc in indexdocs_ordered_word2vec[n_documents*2:n_documents*3]:
    result = rsdata.find_indexdoc(ix_data_sample, idoc)
    for r in result:
        print(r['indexdoc'], r['bag_of_words'])
# Out:
# First 100 documents in the ordered graph
#
# index97023 algol simulation 68
# index288618 partitioning algorithm
# index201353 partitioning algorithm logic
# index111566 graphical spatial applications audio
# index74743 metaphors spatial spatialization user interfaces
# index234054 graphs interfaces computer human
# index525961 approach integrated dynamic manufacturing systems modeling
# index171162 partitioning nonparametric algorithm multiclass
# index256988 analysis workstations design multimedia subsystem
# index486928 principles interfaces design human computer
# index189817 analysis networks multilayer neural optimization
# index541978 interfaces computer human cognitive complexity
# index81445 data echnical warehousing architecture
# index467054 ecl risc mips implementation cmos architecture
# index363994 approach performance testing integrated analysis systems parallel
# index186267 based software system module rigi construction interface model evolution specifications integration
# index148329 human interfaces design issues computer
# index278255 analysis cryptography neural
# index291675 programs logic probabilistic temporal
# index291415 object visual data management analysis tool
# index562772 evolutionary approach database data architecture warehousing
# index218672 neural analysis applications regression network
# index178093 toolpack implementation workstation graphics use
# index608368 neural analysis network models
# index371124 clustering optimal dbms relational method complex domains access functional
# index328011 using overhead datapaths design managing reconfigurable chip networks dynamic reconfiguration optimized systems interconnection
# index269358 software engineering expert system metrics process measurement product
# index4479 technology performance digital storage transmission information processing analysis systems modeling
# index461163 analysis networks neural redundancy
# index85150 based recursive efficient logic verification hannibal tool learning
# index234021 dynamic reconfiguration
# index33104 dynamic reconfiguration
# index481617 risc architecture mips
# index264454 based interfaces fddi digital audio
# index356590 adaptive interfaces computer human toward
# index96699 internet based dynamically workflows reconfigurable desktop environments paradigm
# index375284 information mobile interfaces retrieval
# index181958 based design intellipse tools knowledge towards commercial data processing systems
# index583048 standard programs logic approach temporal
# index151053 natural database language management development systems interfaces considerations
# index366376 irregular routing networks reconfiguration analysis tool algorithms
# index558260 applications qos reconfigurable framework multimedia support dynamically
# index187483 performance nonstationary stochastic processes gradient algorithms tracking
# index379449 human computer generating adaptive self interfaces
# index186435 design reasoning expert system knowledge empirical interface presentation intelligent development systems assessment framework
# index465427 data into analysis visual 90s
# index233546 data analysis visual exploration
# index254704 data analysis visual exploration
# index366382 towards verification quantitative probabilistic transition systems
# index557243 visual mining data method analysis curricula
# index89133 reuse based spatial storage serial scalability interfaces
# index255910 algebraic approach analysis programs logic sharing
# index367983 bayesian inference adaptive alignment
# index215389 image system visual data processing analysis medical
# index539693 design system matrix scenarios modelling user exercise results
# index582787 systems distributed monitoring
# index216752 systems distributed monitoring
# index172080 quadratic skew forms schur functions
# index395107 analysis stability networks neural
# index268884 interfaces patterns human computer safer
# index355212 services transactional approach government integrated
# index224060 computing algorithm graded algebras
# index261221 operators system spatial database relational strong domains integration
# index188950 approach reconfigurable machine virtual dynamically parallel
# index80087 bayesian approximation algorithm inference optimal
# index323145 variables random discrete generating computer
# index592340 specification system unified tools case integrated language information development
# index361262 based finite state semantics verification systems tool
# index378798 telecommunications transactional configuring approach services
# index382031 semantics their programs logic probabilistic
# index270727 information implementing systems management security
# index378812 risc embedded applications lr33000 mips control compatible architecture processor
# index570118 combining methods statistical relational domains hypertext learning
# index115533 impact aggregation wireless data sensor networks density network
# index589476 mdash design inference hardware implementation fuzzy architecture systems
# index208040 reasoning human approach knowledge computer user about network dynamic adaptive domain fuzzy neural interfaces logic modeling level
# index462595 gmms system design conceptional model management decision support systems framework distributed global
# index200767 types synthesis towards data theory abstract automating implementations program
# index357808 system evolution design rationale supporting
# index473149 approach integrated structure ai industry competitive analysis systems modeling
# index187801 analysis visual data supporting environment scientific
# index536235 tuple design optimal partitioning ordering schema storage combined attribute
# index530734 workstation graphics tactile
# index206274 processing virtual parallel machine vmpp
# index367666 pipeline database supporting management architecture systems parallel
# index281908 extraction inductance techniques efficient complex geometries
# index366214 applications divisible linear scheduling layered networks heterogeneous tasks arrays
# index469311 economics integrated context business ai systems modeling
# index480518 trajectories optimal principle processes maximum discontinuous
# index361552 using specification hardware verification experience prolog
# index263286 based software engineering conceptual model architecting mbase challenges modeling
# index603853 services integrated control evaluation networks dynamic fast
# index441423 pcs simple_1 simulation siman
# index76346 software tools flexible suite simulation witness
# index327869 natural various stochastic adaptive algorithms gradient learning models
# index560525 cryptography visual neural general paradigm network
# index374369 using hoare verifying like probabilistic programs logic
# index275167 normative new theory probabilistic summary logic
# index450588 workstation graphics standards
# index358946 based services knowledge transactional platform smartgov electronic
#
#
# Last 100 documents in the ordered graph
#
# index160859 extracting lines straight
# index153037 extracting lines straight
# index94010 hull bounded complete space agr
# index525587 information preparation future teacher searching
# index160494 exhaustive 33 matrices order type cm hadamard cq williamson search
# index214385 place 1992 conference interdisciplinary october design supported report computer during cooperative acm first took work day cscw describes 31 which workshop reports theory
# index625162 internet 1st essential guide health psychotherapists edition mental professionals other
# index4890 2007 office microsoft step excel
# index525816 volumes irregular fast traverse
# index618648 accounting problems principles ed 3rd
# index519609 interpretation mdash issue part scenes special
# index515189 motion shape sequence images recovering
# index213357 motion shape sequence images recovering
# index254567 1st assembly edition language programming ibm pc
# index236945 symposium south communications processing signal proceedings african comsig
# index786 dummies express fur 2005 visual web edition developer
# index293194 two construction dimensional suffix line trees
# index247458 mmixware risc 1st third computer edition millennium
# index90439 distance bounded graphs regular
# index597396 information cut representation branch
# index50245 up academic online publishing call era pricing wake
# index567254 ps algol distributed
# index468473 future searching
# index246735 perspective south chi consortium 2002 development african
# index176602 workstations office home commentary
# index245844 creative stories relate around used book entire vocabulary authorship children out introduction artist unlock art told trying into make world all experiencing expanded illustrator sense education pictures process has drawing were arisman marshall
# index290043 normal two stage distributions multiple average heteroscedasticity under comparisons
# index589168 internet does rdquo teaching first which chicken ldquo what egg mean comes
# index151327 distance graphs halved regular
# index530766 geometries semipartial nets covered subplane
# index626723 internet 1st consumers guide health resources librarians edition care
# index78807 tomorrow making assisted schools computer decision preconditions
# index266004 proof explicit nets substitutions
# index452650 conference mdash 89 third international workshop petri performance report nets models pnpm
# index210008 development up wake professional
# index462694 tomorrow yesterday information today systems executive
# index307680 maner commentary paper
# index312716 maner commentary paper
# index583682 net clock zero construction general skew
# index109409 2003 microsoft coursecard introductory office edition access illustrated
# index10655 brief xp 2003 microsoft windows learning office edition thompson illustrated
# index14962 out excel microsoft office inside 2007
# index380515 offs trade space
# index475645 os expert opinion
# index626952 internet world 1st guide wide health annual medicine web edition
# index86519 computing overview celebration reflections overshadowed realized so was plankalk context alma public mind called university berlin puts overtaken konrad revised little however 1943 computer war ii shortened outside language developed works zuse technical his author level world contributions 1945 1941 mater first gives also work eulogy high inventions former known essay germany birthday german aiken 80th uuml relatively von pioneer neumann programming were december 1996 functioning version
# index476181 lines counting straight
# index80057 range searching
# index101444 brief 2003 microsoft coursecard office edition access illustrated
# index48228 excel section microsoft editorial special 2007
# index326400 pruning multi agr cut tree game bgr search
# index369084 konrad t3d cray zentrum berlin machine zuse production
# index257542 atr neuron report billion three artificial progress cam year brain project
# index51917 methodology up coffee century smell evaluation 21st wake
# index251696 internet 1st health resources edition care
# index16404 xp 2003 office edition 5th access guidebook
# index274579 protect against exhaustive key how des search
# index36400 held conference cikm 9th widm acm report international 16th workshop was lisbon knowledge conjunction data information web management portugal 2007 november
# index619324 california biokdd01 san conference bioinformatics report international knowledge mining 7th francisco conjunction 2001 discovery 26 held acm provide usa august workshop sigkdd data summary
# index146370 ldquo rdquo programming fill form
# index213770 airline problems crew solving scheduling branch cut
# index592154 power out clocking hot pentiums macs products beat
# index326714 should graded memberships acm
# index168655 databanks alert american
# index569965 transform parametrization hough
# index284053 expert opinion
# index210038 ultraportable worth offs pcs trade
# index53915 communication rdquo publishers change ape journal conference european sinus arend scenario ster marketing presentation pcg oxford day 2007 embracing group treatments workshop uuml pre ldquo nuclear europe
# index618290 macworld office home companion
# index147503 foiling key attack search exhaustive
# index619326 bacon internet 1st guide 1998 quick allyn health edition
# index358682 report pre workshop conference
# index347325 factory home office laboratory vlsi
# index563 introductory korn programming shell
# index313712 mdash konrad uuml revisited plankalk zuse
# index173496 databanks march european
# index211022 distance ki graphs kj regular
# index475176 home office tech hi
# index464656 question education first which chicken competing nursing egg came ivd
# index531264 egg chicken problem
# index390748 replies authors commentary
# index338683 commentary
# index325924 commentary
# index33154 commentary
# index305598 commentary
# index247584 commentary
# index555985 stars scheduling off call line trees
# index277261 pivotal offs qpns pruning trade
# index254333 internet cheating up call plagiarism student era wake
# index155264 mc68824 token controller factory bus vlsi lan
# index618773 5th pascal edition
# index616748 1st hitchhiker guide online america edition
# index539070 queue fair man distributed fdq
# index377298 pruning cut branch isomorphism
# index12367 telecommunications 5th edition
# index310011 falling commentary morpheus
# index219932 cuckoo egg revisited
# index481573 caution sprint
# index287797 wright commentary
# index102744 sublanguage algol 68
#
# 100 documents in the ordered graph
#
# index205014 retrieval bases large optimal partitioning data multiple rectangular attribute
# index416749 automatic workflows wrapper generation information environment enabling grid integration
# index151156 systems tomorrow hardware fuzzy
# index95398 hysteretic oscillators synchronization responses self coupled
# index370600 techniques knowledge multimedia some learning enabling exploitation
# index259810 mining visual oriented category data analysis
# index346590 optimal matrix principle information method gradient memory throughout associative processes analog adaptive algorithms use shown distributed learning selectivity formed which related transform
# index262027 system comemo knowledge community supporting evolution
# index188360 metaknowledge based retrieval system expert knowledge distributed information office heuristics architecture automation learning
# index186135 implications structures human knowledge problem computer solving interactive tasks
# index585057 using controller multi intelligent fuzzy assessment logic
# index523025 moment variables generating function given sequence random discrete algorithms
# index209612 approach partitioning attribute oriented transaction
# index199006 multimodal stochastic multidimensional searching gradient algorithms surfaces
# index283915 based constraint propagation algorithm coordination iteration chaotic
# index276652 classification adaptive graphs acyclic directed multiclass
# index315000 gain inference processes computational information reinforcement measures
# index481037 polynomially graded logic
# index522420 update lazy evaluation algorithm incremental flexible attribute
# index371945 human interaction problem research solving computer
# index267245 based system base schema er three data architecture management level
# index360563 verified tomorrow asynchronous hardware digital
# index453448 incorporates concepts special modeling siman paper simulation handling purpose material introduction features language components general using methods simulating manufacturing enhance discusses system which greatly systems simplify
# index331153 based communication linguistically conceptual business modeling
# index361318 structures activity knowledge debugging problem oriented solving application domain their
# index205190 design resonant computer dc converters analysis aided
# index180754 analysis variable converters state dc
# index316341 variables efficient generating method distributions general random discrete
# index176279 neural networks part primer
# index486956 neural networks part primer
# index82207 incorporates concepts special modeling siman paper simulation handling component purpose material introduction features language general using methods these simulating manufacturing enhance discusses system which greatly systems simplify
# index284031 bayesian inference introduction networks
# index86069 strategic operational edi development conceptual measuring means benefits self assessment framework
# index553713 computing calculation algebraic design integrals atomic provides algebra overcoming use doing symbolic difficulties application physics implications manipulation certain interesting numerical complications systems computation
# index567431 external complexity graphs iii rectangle visibility
# index544061 discipline creative making visualization modeling
# index547181 incorporates concepts special siman paper simulation handling component new purpose material introduction features language simplify general using methods these simulating manufacturing enhance discusses system which greatly systems modeling
# index554423 incorporates concepts special siman paper simulation handling component new purpose material introduction features language simplify general using methods these simulating manufacturing enhance discusses system which greatly systems modeling
# index509768 introductory mathematics programming discrete
# index589085 verification prolog program
# index117230 verification prolog program
# index280942 set applications constraint bayesian approximation feedback problem inference satisfaction algorithms vertex
# index362935 constraint maintenance propagation local systems formalizing
# index458064 analysis excitability neural oscillations
# index362276 scalable classifier mining data sprint parallel
# index14858 fundamental principles accounting
# index366311 study services approach telecommunications case integrated educational
# index166374 theory graded structures
# index182839 normal variables generating order distribution algorithm random
# index270168 based relational few numerical abstract domains graph
# index370960 monitoring support interoperability systems distributed line
# index590068 filters sliding efficient transform implementation transforms adaptive domain
# index583522 retrieval system text full compression adding
# index110404 impact variability clock process analysis skew
# index171616 workstation graphics towards
# index282526 communications mobile high multimedia audio coding quality
# index540630 applications digital principles systems 5th ed
# index172362 generator codes matrices mds
# index372896 solution processing soc massive parallel
# index313608 coefficients acoustic new problems interface dimensional one method hyperbolic example discontinuous
# index219988 codes elliptic mds
# index219955 robots serial implementation multiple coordination area local algorithms network
# index200596 pattern template pictorial matching algorithm recognition generalized
# index521919 optimal representation networks graphs acyclic activity directed
# index222677 numeration linear recurrences sets systems regular
# index151145 massively ops5 execution machine production parallel systems
# index593846 computing pseudo via graph triangulations visibility
# index584151 feedback generation speech non support audio interfaces tool
# index147134 system design new meet needs dc converters
# index182701 programs abstract machine execution restricted logic parallel
# index221863 aggregates modularity concurrent massively supporting programs parallel
# index236248 implementing kerberos security
# index568855 minimum time optimal convex space hull algorithms
# index12765 accounting principles applications excel
# index76209 buffer tail usage single power utilizing distributions multiple servers systems comparison network
# index78384 using noisy globally control oscillators synchronization adaptive environments coupled chaotic
# index288183 multi design system timetabling bus tiered
# index109611 recommendations algol representation hardware 68
# index222431 xele mdash model graphics workstation building polypeptide program
# index82383 cyclic codes mds arcs pseudo
# index255014 fault adaptive programs pvm tolerant
# index278610 system materials monitoring procurement support decision management
# index440745 challenges hardware fuzzy
# index374575 based specification computing unified symbolic language algebra
# index276943 shipbuilding process integrated why industry product how modeling
# index450804 mdash graphical pica development tool program
# index355602 explicit predicates logic substitutions
# index154790 neural networks iii part primer
# index154382 multi machine prolog execution sequential parallel
# index260681 fdts common model abstract machine execution parallel
# index533064 time animation graphics workstation 4d 3d real
# index621962 business rule oriented modeling conceptual
# index521316 systems symbolic research algebra teaching
# index367229 based fault tolerant scheduling multiple processors evolution programs
# index106277 standard ifip document report representation hardware algol 68
# index265190 implementation multiple diagram domain decision package
# index511139 automata cellular sets ohgr sofic systems regular
# index158539 neural networks ii part primer
# index268518 based qos aware ip networks management framework policy
# index430137 impact conceptual process business modeling spectrum changing

# %%
result = rsdata.find_indexdoc(ix_data, "index582787 OR index216752", doc_limit=None)
for r in result:
    print(r)
# Out:
# <Hit {'content': 'Monitoring distributed systems', 'bag_of_words_title': 'systems distributed monitoring', 'bag_of_words': 'systems distributed monitoring', 'cardinality': 3, 'indexdoc': 'index216752', 'title': 'Monitoring distributed systems'}>
# <Hit {'content': 'Monitoring distributed systems', 'bag_of_words_title': 'systems distributed monitoring', 'bag_of_words': 'systems distributed monitoring', 'cardinality': 3, 'indexdoc': 'index582787', 'title': 'Monitoring distributed systems'}>

# %%
# fig = plt.figure(figsize=(3,3))
A = tf.convert_to_tensor(word2vec_approximation)
B = tf.convert_to_tensor(jaccard_approximation)
A_B = A - B

with sess.as_default():
    Af1 = tf.sqrt(tf.trace(tf.matmul(A,tf.transpose(A)))) # Frobenius
    Af2 = tf.norm(A, ord='fro', axis=[1,0]) # Frobenius
   
    print("fnorm(A) ", Af1.eval(), Af2.eval())
 
    A_Bf1 = tf.norm(A_B, ord='fro', axis=[1,0]) # Frobenius

    print("fnorm(A - B) ", A_Bf1.eval())

    
    #plt.imshow(A.eval()[:,word2vec_indices][word2vec_indices,:])
    #plt.colorbar()
    #plt.show()
# Out:
# fnorm(A)  101.52154 101.52159
# fnorm(A - B)  95.75486
