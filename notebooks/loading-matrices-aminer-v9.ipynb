# %%
import matplotlib.pyplot as plt
import matrices.loading as mload

data_path = "resources/aminer/v9" # 629814 documents

csr_matrix_jaccard = mload.load_matrix_jaccard_sim(data_path) # 998 documents sample
csr_matrix_word2vec = mload.load_matrix_word2vec_sim(data_path) # 998 documents sample
# Out:
# Loading indexed jaccard ...
# Preparing to read  1000 measures
# 1000 1000 1000
# Loading indexed word2vec ...
# Preparing to read  1000 measures
# 1000 1000 996

# %%
print(csr_matrix_jaccard.ndim, csr_matrix_jaccard.shape)
print(csr_matrix_word2vec.ndim, csr_matrix_word2vec.shape)
# Out:
# 2 (1000, 1000)
# 2 (1000, 1000)

# %%
plt.matshow(1 - csr_matrix_jaccard.todense(), cmap='hot')
plt.matshow(csr_matrix_word2vec.todense(), cmap='hot')
plt.show()

# %%
plt.matshow((1 - csr_matrix_jaccard.todense()) - csr_matrix_word2vec.todense(), cmap='hot')
plt.show()
