# %% [markdown]
# # Jaccard and word2vec matrices

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy.spatial as sp

import similarities.loading as sl
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
plt.rcParams["figure.figsize"] = (12,12)
mpl.rcParams['image.cmap'] = 'jet'

# %%
data_path = "resources/aminer/v9"
related_docs = False

# %% [markdown]
# Load sparse matrix with jaccard similarities.

# %%
matrix_jaccard = sl.load_matrix_jaccard_sim(data_path, related_docs=related_docs) # 998 documents sample
print(matrix_jaccard.ndim, matrix_jaccard.shape)
# Out:
# path resources/aminer/v9/measures-100-10-0-random-fullcontent-jaccard.bin
# Loading measures from file ...
#  - 500500 measures loaded from resources/aminer/v9/measures-100-10-0-random-fullcontent-jaccard.bin
# Sample size: 1000 documents
#  - Content from resources/aminer/v9/sample-ids-100-10-0-random-fullcontent.bin
# 2 (1000, 1000)

# %% [markdown]
# Load sparse matrix with word2vec similarities.

# %%
matrix_word2vec = sl.load_matrix_word2vec_sim(data_path, related_docs=related_docs) # 998 documents sample
print(matrix_word2vec.ndim, matrix_word2vec.shape)
# Out:
# path resources/aminer/v9/measures-100-10-0-random-fullcontent-word2vec.bin
# Loading measures from file ...
#  - 500500 measures loaded from resources/aminer/v9/measures-100-10-0-random-fullcontent-word2vec.bin
# Sample size: 1000 documents
#  - Content from resources/aminer/v9/sample-ids-100-10-0-random-fullcontent.bin
# 2 (1000, 1000)

# %%
N = matrix_jaccard.shape[0]
print("Number of documents", N, (matrix_jaccard.shape))
# Out:
# Number of documents 1000 (1000, 1000)

# %% [markdown]
# ## Jaccard similarity

# %%
plt.imshow(matrix_jaccard)
plt.colorbar()

# %% [markdown]
# ## Dice from Jaccard

# %%
matrix_dice = np.divide(np.multiply(matrix_jaccard,2), np.add(matrix_jaccard, 1))
print(matrix_dice.shape)

plt.matshow(matrix_dice)
plt.colorbar()
# Out:
# (1000, 1000)

# %% [markdown]
# ## Jaccard disimilarity

# %%
matrix_jaccard_dis = np.subtract(1, matrix_jaccard)
print(matrix_jaccard_dis.shape)

plt.matshow(matrix_jaccard_dis)
plt.colorbar()
# Out:
# (1000, 1000)

# %% [markdown]
# ## word2vec similarity.

# %%
plt.matshow(matrix_word2vec)
plt.colorbar()
